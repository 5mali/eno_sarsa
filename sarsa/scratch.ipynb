# %%
# %matplotlib inline

# %%
import pulp
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math

# %%
np.array([2,4,6])
# Out:
# array([2, 4, 6])

# %%
a = [1,2]
x = np.random.rand(4,4)

# %%
x
# Out:
# array([[0.76746777, 0.79153526, 0.90780534, 0.96626503],
#        [0.10791702, 0.62417238, 0.93108214, 0.91599241],
#        [0.85114327, 0.16926444, 0.71296187, 0.83498152],
#        [0.32861768, 0.57479929, 0.80975893, 0.75169325]])

# %%
x=np.vstack([x, [0,0,0,0]])

# %%
(x[4]==0).all()
# Out:
# True

# %%
x[3,:]
# Out:
# array([0.32861768, 0.57479929, 0.80975893, 0.75169325])

# %%
z = np.array([0,0,0,0])

# %%
(z == 0).all()
# Out:
# True

# %%
j = []

# %%
j.append(2)

# %%
j
# Out:
# [2]

# %%
j.append(4)

# %%
j
# Out:
# [2, 4]

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import time

def pltsin(ax, colors=['b']):
    x = np.linspace(0,1,100)
    if ax.lines:
        for line in ax.lines:
            line.set_xdata(x)
            y = np.random.random(size=(100,1))
            line.set_ydata(y)
    else:
        for color in colors:
            y = np.random.random(size=(100,1))
            ax.plot(x, y, color)
    fig.canvas.draw()

fig,ax = plt.subplots(1,1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
for f in range(5):
    pltsin(ax, ['b', 'r'])
    time.sleep(1)

# %%
x = np.zeros(0)

# %%
x
# Out:
# array([], dtype=float64)

# %%
 x = np.append(x,2)

# %%
x
# Out:
# array([2.])

# %%
mylist = [(A,8), (A,3), (A,3), (A,3)]
def indices( mylist, value):
    return [i for i,x in enumerate(mylist) if x==value]

print (indices(mylist, (A,3)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-0d94637e9c57> in <module>
# ----> 1 mylist = [(A,8), (A,3), (A,3), (A,3)]
#       2 def indices( mylist, value):
#       3     return [i for i,x in enumerate(mylist) if x==value]
#       4
#       5 print (indices(mylist, (A,3)))
#
# NameError: name 'A' is not defined

# %%
z = ["a","b","c"]

# %%
m = [x for i,x in enumerate(z)]

# %%
m
# Out:
# ['a', 'b', 'c']
