# %%
# %matplotlib inline

# %%
import pulp
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

import pandas as pd
import numpy as np
from random import shuffle
from mpl_toolkits.mplot3d import Axes3D

# %%
# Hyper Parameters
LR = 0.2                   # learning rate
EPSILON = 0.7               # greedy policy
GAMMA = 0.9                 # reward discount
LAMBDA = 0.9                # parameter decay

N_ACTIONS = 10 #no. of duty cycles (0,1,2,3,...,10)
BMIN = 0.0
BMAX = 20000.0 #Battery capacity
BOPT = 0.6 * BMAX #Assuming 60% of battery is the optimal level
HMAX = 1000
DMAX = 500
DMIN = 100

# %%
class ENO(object):
    def __init__(self, year=2010, shuffle=False):
        self.shuffle = shuffle
        self.year = year
        self.day = None
        self.hr = None
        
        self.TIME_STEPS = None
        self.NO_OF_DAYS = None
        
        self.BMIN = BMIN
        self.BMAX = BMAX #Battery capacity
        self.BOPT = 0.6 * self.BMAX #Assuming 60% of battery is the optimal level
        self.HMAX = HMAX
        
        self.senergy = None #matrix with harvested energy data for the entire year
        self.fforecast = None #matrix with forecast values for each day
        
        self.batt = None #battery variable
        self.enp = None #enp at end of hr
        self.henergy = None #harvested energy variable
        self.fcast = None #forecast variable
        self.sorted_days = [] #days sorted according to day type
    
    #function to map total day energy into day_state
    def get_day_state(self,tot_day_energy):
        if (tot_day_energy < 2500):
            day_state = 0
        elif (2500 <= tot_day_energy < 5000):
            day_state = 1
        elif (5000 <= tot_day_energy < 8000):
            day_state = 2
        elif (8000 <= tot_day_energy < 10000):
            day_state = 3
        elif (10000 <= tot_day_energy < 12000):
            day_state = 4
        else:
            day_state = 5
        return int(day_state)

    #function to get the solar data for the given year and prep it
    def get_data(self):
        filename = str(self.year)+'.csv'
        #skiprows=4 to remove unnecessary title texts
        #usecols=4 to read only the Global Solar Radiation (GSR) values
        solar_radiation = pd.read_csv(filename, skiprows=4, encoding='shift_jisx0213', usecols=[4])
        
        #convert dataframe to numpy array
        solar_radiation = solar_radiation.values
        solar_energy = np.array([i *0.0165*1000000*0.15*1000/(60*60) for i in solar_radiation])
        
        #reshape solar_energy into no_of_daysx24 array
        _senergy = solar_energy.reshape(-1,24)
        _senergy[np.isnan(_senergy)] = 0 #convert missing data in CSV files to zero
        if(self.shuffle):
            np.random.shuffle(_senergy) #if class instatiation calls for shuffling the day order. Required when learning
        self.senergy = np.clip(_senergy,0,self.HMAX) #limit the amount of harvested energy to HMAX        
        
        #create a perfect forecaster
        tot_day_energy = np.sum(_senergy, axis=1) #contains total energy harvested on each day
        get_day_state = np.vectorize(self.get_day_state)
        self.fforecast = get_day_state(tot_day_energy)
        
        for fcast in range(0,6):
            fcast_days = ([i for i,x in enumerate(self.fforecast) if x == fcast])
            np.random.shuffle(fcast_days)
            self.sorted_days.append(fcast_days)
    
        return 0
    
    def reset(self,day=0):
        
        self.get_data() #first get data for the given year
        
        self.TIME_STEPS = self.senergy.shape[1]
        self.NO_OF_DAYS = self.senergy.shape[0]
        
        print("Environment is RESET")
        
        self.day = day
        self.hr = 0
        
        self.batt = self.BOPT #battery returns to optimal level
        self.enp = self.BOPT - self.batt #enp is reset to zero
        self.henergy = self.senergy[self.day][self.hr] 
        self.fcast = self.fforecast[self.day]
        
        norm_batt = self.batt/self.BMAX
        norm_enp = self.enp/(self.BMAX/2)
        norm_henergy = self.henergy/self.HMAX
        norm_fcast = self.fcast/5

        state = [norm_batt, norm_enp, norm_henergy, norm_fcast]
        reward = 0
        done = False
        info = "RESET"
        return [state, reward, done, info]
    
    
    #reward function
    def rewardfn(self):
        mu = 0
        sig = 1000
        norm_enp = self.enp/(self.BMAX/2)
        if(np.abs(norm_enp) <= DMIN*self.TIME_STEPS/(BMAX/2)): # DMIN*self.TIME_STEPS/(BMAX/2) - normalized value of worst case power consumption at min duty cycle
            return ((1./(np.sqrt(2.*np.pi)*sig)*np.exp(-np.power((self.enp - mu)/sig, 2.)/2)) * 1E6)
        else:
            return -100 - 0.05*np.abs(self.enp)
    
    def step(self, action):
        done = False
        info = "OK"
        reward = 0
        e_consumed = (action+1)*DMAX/N_ACTIONS
        
        self.batt += (self.henergy - e_consumed)
        self.batt = np.clip(self.batt, self.BMIN, self.BMAX)
        self.enp = self.BOPT - self.batt
        
        if(self.hr < self.TIME_STEPS - 1):
            self.hr += 1
            self.henergy = self.senergy[self.day][self.hr] 
        else:
            if(self.day < self.NO_OF_DAYS -1):
                reward = self.rewardfn() #give reward only at the end of the day
                self.hr = 0
                self.day += 1
                self.henergy = self.senergy[self.day][self.hr] 
                self.fcast = self.fforecast[self.day]
            else:
                reward = self.rewardfn()
                done = True
                info = "End of the year"
        
        norm_batt = self.batt/self.BMAX
        norm_enp = self.enp/(self.BMAX/2)
        norm_henergy = self.henergy/self.HMAX
        norm_fcast = self.fcast/5

        _state = [norm_batt, norm_enp, norm_henergy, norm_fcast]
        return [_state, reward, done, info]
                
        #we normalize the enp w.r.t. half of the battery level
        #this may give weird results if BOPT varies by a great amount from 0.5*BMAX
    
    def getstate(self):
        norm_batt = self.batt/self.BMAX
        norm_enp = self.enp/(self.BMAX/2)
        norm_henergy = self.henergy/self.HMAX
        norm_fcast = self.fcast/5
        state = [norm_batt, norm_enp, norm_henergy, norm_fcast]
               
        return state

# %%
class SARSA(object):
    def __init__(self):
        self.no_of_batt_state = 3;
        self.no_of_enp_state = 42;
        self.no_of_henergy_state = 30;
        self.no_of_day_state = 6;
        self.no_of_actions = N_ACTIONS;
        self.q_init = 200;
        self.q = np.zeros((self.no_of_batt_state, self.no_of_enp_state, self.no_of_henergy_state, self.no_of_day_state, self.no_of_actions)) + self.q_init
        self.e = np.zeros_like(self.q)

    
    def get_batt_state(self,batt):
        if (batt < 0.3):
            batt_state = 0
        elif (0.3<= batt <0.8):
            batt_state = 1
        else:
            batt_state = 2
        
        return int(batt_state)
    
    def get_enp_state(self,enp):
        #assuming the battery deviates equally in both enp directions
        #NEEDS TO BE RETHOUGHT AND UPDATED
#         enp_max = 0.5
#         enp_min = 0
        
        enp = np.clip(enp,-0.5,0.5)
        _enp = 0.5 + enp
        enp_state = np.ceil(_enp*self.no_of_enp_state)
        
        enp_state = np.clip(enp_state, 0, self.no_of_enp_state-1)
        return int(enp_state)
    
    def get_henergy_state(self,henergy):
        henergy_state = int(np.floor(henergy*self.no_of_henergy_state))
        henergy_state = np.clip(henergy_state, 0, self.no_of_henergy_state-1)
        return int(henergy_state)
    
    def get_fcast_state(self,fcast):
        return fcast * 5
    
    def discretize(self,ps):
        s = np.zeros(4)
        s[0] = self.get_batt_state(ps[0])
        s[1] = self.get_enp_state(ps[1])
        s[2] = self.get_henergy_state(ps[2])
        s[3] = self.get_fcast_state(ps[3])
        return s.astype(int)
        
    def choose_action(self,s):
        [batt_state, enp_state, henergy_state, day_state] = s
        # This is how to choose an action
        q_values = self.q[batt_state, enp_state, henergy_state,  day_state, :]
        max_q_value = np.max(q_values)
        max_action = np.argmax(q_values)
        if (np.random.uniform() < EPSILON) or ((q_values == 0).all()):  # select randomly if exploring or 
                                                                             #if state-action values are ALL zero
            action = np.random.randint(1,N_ACTIONS)
        else:   # act greedy
            action = max_action
        return int(action)
    
    def choose_greedy_action(self,s):
        [batt_state, enp_state, henergy_state, day_state] = s
        # This is how to choose an action
        q_values = self.q[batt_state, enp_state, henergy_state,  day_state, :]
        max_q_value = np.max(q_values)
        max_action = np.argmax(q_values)
        if ((q_values == 0).all()):  #if state-action values are ALL zero
             action = np.random.randint(1,N_ACTIONS)
        else:   # act greedy
            action = max_action
        return int(action)
    
    def learn(self,transition, terminal):
        [s,a,r,s_,a_] = transition
        [batt_state, enp_state, henergy_state, day_state] = s
        [batt_state_, enp_state_, henergy_state_, day_state_] = s_
        
        if (terminal):
            del_ = r - self.q[batt_state, enp_state, henergy_state, day_state, a]
        else:
            del_ = GAMMA*self.q[batt_state_, enp_state_, henergy_state_, day_state_, a_] \
                    - self.q[batt_state, enp_state, henergy_state, day_state, a]
       
        #update eligibility trace and q-table
        self.e[batt_state, enp_state, henergy_state,  day_state, a] += 1
        qerr = LR*del_*self.e
        self.q += qerr #update the entire qtable
        self.e = GAMMA*LAMBDA*self.e #decay eligibility

# %%
eno = ENO(2010)
eno.reset()
sarsa = SARSA()
# Out:
# Environment is RESET

# %%
# #Check reward function
# #ENP varies from -0.5 to 0.5
# y1 = np.empty(1)
# for x in np.arange(-5000,5000):
#     eno.enp = x
#     y1 = np.append(y1,eno.rewardfn())
# y1 = np.delete(y1, 0, 0) #remove the first row which is garbage

# #Check state discretiziation functions
# #Battery value varies from 0 to 1
# y2 = np.empty(1)
# for x in np.arange(0,1,0.01):
#     temp = sarsa.get_batt_state(x)
#     y2 = np.append(y2,temp)
# y2 = np.delete(y2, 0, 0) #remove the first row which is garbage

# #Check state discretiziation functions
# #ENP value varies from -0.5 to 0.5
# #Inconsistent with the reward function 
# y3 = np.empty(1)
# for x in np.arange(-0.5,0.5,0.01):
#     temp = sarsa.get_enp_state(x)
#     y3 = np.append(y3,temp)
# y3 = np.delete(y3, 0, 0) #remove the first row which is garbage

# #Check state discretiziation functions
# #henergy value varies from 0 to 1
# y4 = np.empty(1)
# for x in np.arange(0,1,0.01):
#     temp = sarsa.get_henergy_state(x)
#     y4 = np.append(y4,temp)
# y4 = np.delete(y4, 0, 0) #remove the first row which is garbage


# ####################################
# ##   PRINT FIGURES##################
# fig = plt.figure(figsize=(16,4))

# ax1 = fig.add_subplot(1,4,1)
# ax1.set_title("Reward")
# ax1.set_xlabel("ENP",color='g')
# ax1.plot(np.arange(-5000,5000),y1,'g')

# ax2 = fig.add_subplot(1,4,2)
# ax2.set_title("Battery States")
# ax2.set_xlabel("Battery (normalized)",color='r')
# ax2.plot(np.arange(0,1,0.01),y2,'r')

# ax3 = fig.add_subplot(1,4,3)
# ax3.set_title("ENP States")
# ax3.set_xlabel("ENP (normalized)",color='y')
# ax3.plot(np.arange(-0.5,0.5,0.01),y3,'y')

# ax4 = fig.add_subplot(1,4,4)
# ax4.set_title("Henergy States")
# ax4.set_xlabel("Henergy (normalized)",color='b')
# ax4.plot(np.arange(0,1,0.01),y4,'b')

# fig.tight_layout()
# plt.show()

# %%
# #TEST FOR ENO_SHUFFLE
# eno_no_shuffle = ENO(2010,shuffle=False)
# eno_shuffle = ENO(2010,shuffle=True)

# print('\nShuffling test')
# ps_no_shuffle, r, done, info = eno_no_shuffle.reset()
# ps_shuffle, r, done_, info = eno_shuffle.reset()

# no_shuffle_record = []
# shuffle_record = []

# no_shuffle_fcast_record = []
# shuffle_fcast_record = []

# while True:
#     no_shuffle_record = np.append(no_shuffle_record, ps_no_shuffle[2])   #record henergy
#     shuffle_record = np.append(shuffle_record, ps_shuffle[2])   #record henergy
    
#     no_shuffle_fcast_record = np.append(no_shuffle_fcast_record, ps_no_shuffle[3])   #record fcast
#     shuffle_fcast_record = np.append(shuffle_fcast_record, ps_shuffle[3])   #record fcast
    
#     ns_no_shuffle, r, done, info = eno_no_shuffle.step(1)
#     ns_shuffle, r, done_, info = eno_shuffle.step(1)

#     if done_:
#         print("End of Year")
#         break
    
#     ps_shuffle = ns_shuffle
#     ps_no_shuffle = ns_no_shuffle


# print("\nWithout Shuffling")
# print(no_shuffle_fcast_record[0*24:15*24:24] * 5)
# print("With Shuffling")
# print(shuffle_fcast_record[0*24:15*24:24] * 5)

# fig = plt.figure(figsize=(16,4))

# ax1 = fig.add_subplot(1,2,1)
# ax1.plot(no_shuffle_record[0*24:15*24])
# ax1.set_title("Without Shuffling")

# ax2 = fig.add_subplot(1,2,2)
# ax2.plot(shuffle_record[0*24:15*24])
# ax2.set_title("With Shuffling")

# fig.tight_layout()
# plt.show()

# %%
sarsa = SARSA()

NO_OF_ITERATIONS = 1000
avg_reward_rec = np.empty(1)

for iteration in range(NO_OF_ITERATIONS):
    if (100< iteration <= 250):
        LR = 0.05                   # learning rate
        EPSILON = 0.7              # greedy policy
    elif (250<iteration<=650):
        LR = 0.01
        EPSILON = 0.8
    elif (650<iteration<=NO_OF_ITERATIONS):
        LR = 0.005
        EPSILON = 0.9
    else:
        LR = 0.1
        EPSILON = 0.7
    
    ############################################################################################
    #LEARN WITHOUT RESETTING BATTERY EVERYDAY AND BY SHUFFLING DAYS
    print('\nCollecting experience... Iteration:', iteration)
    print('Learning Rate = ', LR)
    print('EPSILON = ', EPSILON)
    
    eno = ENO(2010, shuffle=False)
    ps, r, done, info = eno.reset()
    
    while True:
        s = sarsa.discretize(ps)
        a = sarsa.choose_action(s)
        ns, r, done, info = eno.step(a)

        #if battery gets full, reset it to optimal value
        if eno.batt >= eno.BMAX:
            eno.batt = eno.BOPT
            ns = eno.getstate()
        
        if eno.batt <= 0.1 * eno.BMAX:
            eno.batt = eno.BOPT
            ns = eno.getstate()
        
        if eno.hr == 0: #flag to let the sarsa algorithm know that the reward has been obtained
            terminal = True
#             eno.batt = eno.BOPT
#             ns = eno.getstate()
        else:
            terminal = False
        
        s_ = sarsa.discretize(ns)
        a_ = sarsa.choose_action(s_)        
        transition = [s,a,r,s_,a_]
        
        sarsa.learn(transition,terminal)
        if done:
            print("End of Year")
            break

        ps = ns
    
    ############################################################################################
    #TEST WITHOUT SHUFFLING DAYS OR RESETTING BATTERY
    eno = ENO(2010, shuffle=False)
    eno.reset()
    print('\nYear run test')
    ps, r, done, info = eno.reset()
    year_test_record = np.empty(4)

    while True:
        s = sarsa.discretize(ps)
        a = sarsa.choose_greedy_action(s)

        year_test_record = np.vstack((year_test_record, [ps[0],ps[2],r, a])) #record battery, henergy, reward and action

        ns, r, done, info = eno.step(a)

            
#         if eno.hr == 0: #flag to let the sarsa algorithm know that the reward has been obtained
#             eno.batt = eno.BOPT
#             ns = eno.getstate()

        s_ = sarsa.discretize(ns)
        a_ = sarsa.choose_action(s_)        

        if done:
            print("End of Year")
            break

        ps = ns

    year_test_record = np.delete(year_test_record, 0, 0) #remove the first row which is garbage
    year_test_reward_rec = year_test_record[:,2]
    year_test_reward_rec = year_test_reward_rec[year_test_reward_rec != 0]
    print("Average Reward: ", np.mean(year_test_reward_rec))
    avg_reward_rec = np.append(avg_reward_rec, np.mean(year_test_reward_rec))


    ############################################################################################
    #PLOT
#     fig = plt.figure(figsize=(24,4))
#     ax1 = fig.add_subplot(121)
#     ax1.plot(year_test_reward_rec)
#     ax1.set_title("Year Run Reward")
#     ax1.set_ylim([-500,500])

#     ax2 = fig.add_subplot(122)
#     ax2.plot(year_test_record[:,0],'r')
#     ax2.set_title("Year Run Battery")
#     # ax2.set_ylim([0,1])

#     fig.tight_layout()
#     plt.show()

#PLOT THE AVERAGE REWARD OVER THE ITERATIONS
avg_reward_rec = np.delete(avg_reward_rec, 0, 0) #remove the first row which is garbage
plt.plot(avg_reward_rec,'g')
# Out:
# Collecting experience... Iteration: 0
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -420.6570167231849
#
# Collecting experience... Iteration: 1
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -451.12740384615387
#
# Collecting experience... Iteration: 2
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -430.39243296737527
#
# Collecting experience... Iteration: 3
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -335.2492263254815
#
# Collecting experience... Iteration: 4
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -335.58475101104636
#
# Collecting experience... Iteration: 5
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -343.547807940598
#
# Collecting experience... Iteration: 6
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -349.9797436686728
#
# Collecting experience... Iteration: 7
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -299.90795393423986
#
# Collecting experience... Iteration: 8
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -363.9337352411041
#
# Collecting experience... Iteration: 9
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -262.26916057658354
#
# Collecting experience... Iteration: 10
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -248.4552840987809
#
# Collecting experience... Iteration: 11
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -414.8704483744249
#
# Collecting experience... Iteration: 12
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -284.0718809077676
#
# Collecting experience... Iteration: 13
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -225.76171665976946
#
# Collecting experience... Iteration: 14
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -274.77298727102016
#
# Collecting experience... Iteration: 15
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -206.42544129127046
#
# Collecting experience... Iteration: 16
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -300.76045360272167
#
# Collecting experience... Iteration: 17
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -392.69413256721367
#
# Collecting experience... Iteration: 18
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -285.41757821450267
#
# Collecting experience... Iteration: 19
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -300.411889888357
#
# Collecting experience... Iteration: 20
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -362.98737065596356
#
# Collecting experience... Iteration: 21
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -271.91171225564506
#
# Collecting experience... Iteration: 22
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -355.72141298112984
#
# Collecting experience... Iteration: 23
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -196.63578679803322
#
# Collecting experience... Iteration: 24
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -278.82125267467853
#
# Collecting experience... Iteration: 25
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -268.5250836106955
#
# Collecting experience... Iteration: 26
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -164.3276736081236
#
# Collecting experience... Iteration: 27
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -257.1073447932761
#
# Collecting experience... Iteration: 28
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -232.93119826076713
#
# Collecting experience... Iteration: 29
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -190.2763497184184
#
# Collecting experience... Iteration: 30
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -198.2765897720665
#
# Collecting experience... Iteration: 31
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -189.57957103464938
#
# Collecting experience... Iteration: 32
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -171.94767873882603
#
# Collecting experience... Iteration: 33
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -206.26685621088828
#
# Collecting experience... Iteration: 34
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -232.12862188351767
#
# Collecting experience... Iteration: 35
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -313.9093266801664
#
# Collecting experience... Iteration: 36
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -273.5807925892003
#
# Collecting experience... Iteration: 37
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -297.10251752461926
#
# Collecting experience... Iteration: 38
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -225.00593998910387
#
# Collecting experience... Iteration: 39
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -210.35978614090902
#
# Collecting experience... Iteration: 40
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -413.3486757253389
#
# Collecting experience... Iteration: 41
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -316.01022729698116
#
# Collecting experience... Iteration: 42
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -151.147309293679
#
# Collecting experience... Iteration: 43
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -150.3616243132511
#
# Collecting experience... Iteration: 44
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -275.7980555708051
#
# Collecting experience... Iteration: 45
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -197.19624822712896
#
# Collecting experience... Iteration: 46
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -205.1160672760468
#
# Collecting experience... Iteration: 47
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -221.61251292684352
#
# Collecting experience... Iteration: 48
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -243.3798407811312
#
# Collecting experience... Iteration: 49
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -242.74956227341949
#
# Collecting experience... Iteration: 50
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -299.35348186512573
#
# Collecting experience... Iteration: 51
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -242.16808225326682
#
# Collecting experience... Iteration: 52
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -236.3196503607066
#
# Collecting experience... Iteration: 53
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -254.136897444105
#
# Collecting experience... Iteration: 54
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -392.1597084942674
#
# Collecting experience... Iteration: 55
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -341.72009346865167
#
# Collecting experience... Iteration: 56
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -239.51743226970692
#
# Collecting experience... Iteration: 57
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -126.25570184604824
#
# Collecting experience... Iteration: 58
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -192.73692928820293
#
# Collecting experience... Iteration: 59
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -165.95693429229246
#
# Collecting experience... Iteration: 60
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -257.8896090312618
#
# Collecting experience... Iteration: 61
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -203.56498345723497
#
# Collecting experience... Iteration: 62
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -193.99967507548098
#
# Collecting experience... Iteration: 63
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -356.3655654714098
#
# Collecting experience... Iteration: 64
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -265.10951071384983
#
# Collecting experience... Iteration: 65
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -200.34206123137847
#
# Collecting experience... Iteration: 66
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -160.2538334029305
#
# Collecting experience... Iteration: 67
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -181.182227538125
#
# Collecting experience... Iteration: 68
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -163.01275422034217
#
# Collecting experience... Iteration: 69
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -225.24689023245597
#
# Collecting experience... Iteration: 70
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -249.9236143100617
#
# Collecting experience... Iteration: 71
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -230.10299789781357
#
# Collecting experience... Iteration: 72
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -361.24223380892954
#
# Collecting experience... Iteration: 73
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -194.19388628426367
#
# Collecting experience... Iteration: 74
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -226.7744367029733
#
# Collecting experience... Iteration: 75
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -228.02157994961613
#
# Collecting experience... Iteration: 76
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -180.31120743028117
#
# Collecting experience... Iteration: 77
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -178.17052097521827
#
# Collecting experience... Iteration: 78
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -258.2618406956436
#
# Collecting experience... Iteration: 79
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -186.44819107809042
#
# Collecting experience... Iteration: 80
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -309.0037026368036
#
# Collecting experience... Iteration: 81
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -172.56349612486898
#
# Collecting experience... Iteration: 82
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -162.43177885554138
#
# Collecting experience... Iteration: 83
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -228.62980352521396
#
# Collecting experience... Iteration: 84
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -199.14713977416713
#
# Collecting experience... Iteration: 85
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -295.16550576661365
#
# Collecting experience... Iteration: 86
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -317.63954221420084
#
# Collecting experience... Iteration: 87
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -271.40241337713337
#
# Collecting experience... Iteration: 88
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -426.3937305453616
#
# Collecting experience... Iteration: 89
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -316.57185141562684
#
# Collecting experience... Iteration: 90
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -291.3873295353696
#
# Collecting experience... Iteration: 91
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -365.905694792299
#
# Collecting experience... Iteration: 92
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -207.72116749627725
#
# Collecting experience... Iteration: 93
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -144.8831895084465
#
# Collecting experience... Iteration: 94
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -261.0724798592072
#
# Collecting experience... Iteration: 95
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -300.3922774051827
#
# Collecting experience... Iteration: 96
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -216.4276628493026
#
# Collecting experience... Iteration: 97
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -306.9363291673002
#
# Collecting experience... Iteration: 98
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -331.1720872478136
#
# Collecting experience... Iteration: 99
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -281.15896619415696
#
# Collecting experience... Iteration: 100
# Learning Rate =  0.1
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -297.9265339241385
#
# Collecting experience... Iteration: 101
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -168.64168002653938
#
# Collecting experience... Iteration: 102
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -213.0748904857723
#
# Collecting experience... Iteration: 103
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -173.55191007948113
#
# Collecting experience... Iteration: 104
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -227.55516217455184
#
# Collecting experience... Iteration: 105
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -291.21454778067425
#
# Collecting experience... Iteration: 106
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -290.6427542442898
#
# Collecting experience... Iteration: 107
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -284.6766963182682
#
# Collecting experience... Iteration: 108
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -145.46273592181626
#
# Collecting experience... Iteration: 109
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -226.46046749131196
#
# Collecting experience... Iteration: 110
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -145.75608770256133
#
# Collecting experience... Iteration: 111
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -344.8359127817013
#
# Collecting experience... Iteration: 112
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -228.40122197334364
#
# Collecting experience... Iteration: 113
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -323.35317134117787
#
# Collecting experience... Iteration: 114
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -259.0942624886956
#
# Collecting experience... Iteration: 115
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -183.51955154217964
#
# Collecting experience... Iteration: 116
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -220.93906078304605
#
# Collecting experience... Iteration: 117
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -240.24613931457628
#
# Collecting experience... Iteration: 118
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -149.09047112687375
#
# Collecting experience... Iteration: 119
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -64.26434268766994
#
# Collecting experience... Iteration: 120
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -87.27973793545705
#
# Collecting experience... Iteration: 121
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -126.04326795270497
#
# Collecting experience... Iteration: 122
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -117.22433356356905
#
# Collecting experience... Iteration: 123
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -144.58197618952588
#
# Collecting experience... Iteration: 124
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -307.47954517209973
#
# Collecting experience... Iteration: 125
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -211.90444191564163
#
# Collecting experience... Iteration: 126
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -271.3041596338102
#
# Collecting experience... Iteration: 127
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -73.08278428726238
#
# Collecting experience... Iteration: 128
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -53.98300310538714
#
# Collecting experience... Iteration: 129
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -127.0971553688647
#
# Collecting experience... Iteration: 130
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -145.36377176882053
#
# Collecting experience... Iteration: 131
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -322.87294719576533
#
# Collecting experience... Iteration: 132
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -125.02619537072795
#
# Collecting experience... Iteration: 133
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -138.27751562963908
#
# Collecting experience... Iteration: 134
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -217.02053261331025
#
# Collecting experience... Iteration: 135
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -330.0901908791041
#
# Collecting experience... Iteration: 136
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -206.74697805305945
#
# Collecting experience... Iteration: 137
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -166.73856642723746
#
# Collecting experience... Iteration: 138
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -84.59629292510066
#
# Collecting experience... Iteration: 139
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -349.2655860087777
#
# Collecting experience... Iteration: 140
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -342.3924043900882
#
# Collecting experience... Iteration: 141
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -322.26390803121643
#
# Collecting experience... Iteration: 142
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -348.4191252032151
#
# Collecting experience... Iteration: 143
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -110.95072347241808
#
# Collecting experience... Iteration: 144
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -41.597479400151435
#
# Collecting experience... Iteration: 145
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -191.0763447170862
#
# Collecting experience... Iteration: 146
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -167.05429024019142
#
# Collecting experience... Iteration: 147
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -232.95281697238536
#
# Collecting experience... Iteration: 148
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -233.9614468816843
#
# Collecting experience... Iteration: 149
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -107.19946652758065
#
# Collecting experience... Iteration: 150
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -148.296506402008
#
# Collecting experience... Iteration: 151
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -195.08982386250807
#
# Collecting experience... Iteration: 152
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -141.28213562025888
#
# Collecting experience... Iteration: 153
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -163.87954570020943
#
# Collecting experience... Iteration: 154
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -125.52221071723393
#
# Collecting experience... Iteration: 155
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -199.15618269365282
#
# Collecting experience... Iteration: 156
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -95.76415253735351
#
# Collecting experience... Iteration: 157
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -121.14172859679265
#
# Collecting experience... Iteration: 158
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -249.1174877593049
#
# Collecting experience... Iteration: 159
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -159.58185953278004
#
# Collecting experience... Iteration: 160
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -108.71841194408509
#
# Collecting experience... Iteration: 161
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -103.50098668412726
#
# Collecting experience... Iteration: 162
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -215.0340745410592
#
# Collecting experience... Iteration: 163
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -264.9394082597394
#
# Collecting experience... Iteration: 164
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -147.7999857715097
#
# Collecting experience... Iteration: 165
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -120.17381548180936
#
# Collecting experience... Iteration: 166
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -204.71562385584548
#
# Collecting experience... Iteration: 167
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -189.95312982690078
#
# Collecting experience... Iteration: 168
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -121.67101376602832
#
# Collecting experience... Iteration: 169
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -85.65690763004264
#
# Collecting experience... Iteration: 170
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -113.60622696411342
#
# Collecting experience... Iteration: 171
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -109.3995944703957
#
# Collecting experience... Iteration: 172
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -111.92256548968452
#
# Collecting experience... Iteration: 173
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -195.25362104123664
#
# Collecting experience... Iteration: 174
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -314.1517183214294
#
# Collecting experience... Iteration: 175
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -131.24718005439198
#
# Collecting experience... Iteration: 176
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -144.61942429167226
#
# Collecting experience... Iteration: 177
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -310.3372773231226
#
# Collecting experience... Iteration: 178
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -347.9818606984128
#
# Collecting experience... Iteration: 179
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -244.34630653017805
#
# Collecting experience... Iteration: 180
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -148.04364822330518
#
# Collecting experience... Iteration: 181
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -270.9024532311673
#
# Collecting experience... Iteration: 182
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -128.30918098519828
#
# Collecting experience... Iteration: 183
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -304.23251764286397
#
# Collecting experience... Iteration: 184
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -206.06154732487838
#
# Collecting experience... Iteration: 185
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -187.1576944822404
#
# Collecting experience... Iteration: 186
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -156.96487032512516
#
# Collecting experience... Iteration: 187
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -166.94803435755117
#
# Collecting experience... Iteration: 188
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -263.4148931628045
#
# Collecting experience... Iteration: 189
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -214.26029018536883
#
# Collecting experience... Iteration: 190
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -85.69599378525955
#
# Collecting experience... Iteration: 191
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -302.74323305751534
#
# Collecting experience... Iteration: 192
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -189.06092184145854
#
# Collecting experience... Iteration: 193
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -127.4715136112725
#
# Collecting experience... Iteration: 194
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -317.69898432327864
#
# Collecting experience... Iteration: 195
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -276.1553423498269
#
# Collecting experience... Iteration: 196
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -346.4112026625434
#
# Collecting experience... Iteration: 197
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -362.4369554902484
#
# Collecting experience... Iteration: 198
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -291.5229943085494
#
# Collecting experience... Iteration: 199
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -169.98792868188812
#
# Collecting experience... Iteration: 200
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -262.3698106883085
#
# Collecting experience... Iteration: 201
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -187.61879262905447
#
# Collecting experience... Iteration: 202
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -202.16071359787085
#
# Collecting experience... Iteration: 203
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -135.73763878683
#
# Collecting experience... Iteration: 204
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -137.45417362543066
#
# Collecting experience... Iteration: 205
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -123.42921474180416
#
# Collecting experience... Iteration: 206
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -115.32222510610926
#
# Collecting experience... Iteration: 207
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -161.23612366876384
#
# Collecting experience... Iteration: 208
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -103.10015683301222
#
# Collecting experience... Iteration: 209
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -155.02044462802832
#
# Collecting experience... Iteration: 210
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -267.7986504330479
#
# Collecting experience... Iteration: 211
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -290.79491664783893
#
# Collecting experience... Iteration: 212
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -332.343301950349
#
# Collecting experience... Iteration: 213
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -299.1898074333535
#
# Collecting experience... Iteration: 214
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -150.5634870555897
#
# Collecting experience... Iteration: 215
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -180.5799118068826
#
# Collecting experience... Iteration: 216
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -123.00662653721855
#
# Collecting experience... Iteration: 217
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -233.6424377385867
#
# Collecting experience... Iteration: 218
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -146.0243973060057
#
# Collecting experience... Iteration: 219
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET
# End of Year
# Environment is RESET
#
# Year run test
# Environment is RESET
# End of Year
# Average Reward:  -140.7673675657418
#
# Collecting experience... Iteration: 220
# Learning Rate =  0.05
# EPSILON =  0.7
# Environment is RESET

# %%
np.save('dynamic_learning_with_shuffle_and_no_battery_reset_1000_iter.npy', sarsa.q)

# %%
# Q-TABLE LEARNED WITH BATTERY RESET
# Q-TABLE VERIFICATION WITHOUT BATTERY RESET
sarsa = SARSA()
sarsa.q = np.load('dynamic_learning_with_shuffle_and_no_battery_reset_1000_iter.npy') 

print('\nYear run test')
ps, r, done, info = eno.reset()
yr_test_record = np.empty(4)

violation = 0
while True:
    s = sarsa.discretize(ps)
    a = sarsa.choose_greedy_action(s)
    yr_test_record = np.vstack((yr_test_record, [ps[0],ps[2],r, a])) #record battery, henergy, reward and action

    ns, r, done, info = eno.step(a)
    
    if eno.batt == eno.BMAX:
#         eno.batt = eno.BOPT
#         ns = eno.getstate()
        violation += 1
    
#     if eno.hr == 0: #flag to let the sarsa algorithm know that the reward has been obtained
#         eno.batt = eno.BOPT
#         ns = eno.getstate()
#         terminal = True
#     else:
#         terminal = False
    
    s_ = sarsa.discretize(ns)
    a_ = sarsa.choose_action(s_)        
#     transition = [s,a,r,s_,a_]

#     sarsa.learn(transition,terminal)
    if done:
        print("End of Year")
        break

    ps = ns

yr_test_record = np.delete(yr_test_record, 0, 0) #remove the first row which is garbage
print("Violations = ", violation)
# Out:
# Year run test
# Environment is RESET
# End of Year
# Violations =  1172

# %%
#PLOT RESULTS OF Q_TABLE VERIFICATION WITHOUT BATTERY RESET
yr_test_reward_rec = yr_test_record[:,2]
yr_test_reward_rec = yr_test_reward_rec[yr_test_reward_rec != 0]

# day_test_reward_rec = day_test_record[:,2]
# day_test_reward_rec = day_test_reward_rec[day_test_reward_rec != 0]


fig = plt.figure(figsize=(24,4))
ax1 = fig.add_subplot(121)
ax1.plot(yr_test_reward_rec)
ax1.set_title("Year Run Reward")
ax1.set_ylim([-500,500])

ax2 = fig.add_subplot(122)
ax2.plot(yr_test_record[:,0],'r')
ax2.set_title("Year Run Battery")
ax2.set_ylim([0,1.2])

fig.tight_layout()
